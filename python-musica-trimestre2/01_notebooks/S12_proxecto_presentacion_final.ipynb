# %% [markdown]
# # S12 — Proxecto final: presentación e reflexión
# **Curso:** Programación Musical con Python — 2º Trimestre
# **Sesión final:** Presentación do proxecto, demo e reflexión
#
# ---
#
# ## 🎯 Obxectivos da sesión
#
# 1. Presentar o proxecto final ao grupo
# 2. Facer unha demo funcional
# 3. Reflexionar sobre o proceso de aprendizaxe
# 4. Recibir e dar feedback construtivo
#
# > ✅ Esta é a culminación do trimestre: **mostrar o que aprendiches pensando música con código**.

# %% [markdown]
# ---
#
# # 📋 PARTE 1: Ficha do proxecto
#
# Completa esta ficha antes da presentación.
#
# | Campo | Resposta |
# |-------|----------|
# | **Título do proxecto** | |
# | **Autor/a(s)** | |
# | **Opción (A/B/C)** | |
# | **Obxectivo principal** | |
# | **Ferramentas usadas** | |
# | **Tempo de traballo (aprox.)** | |

# %% [markdown]
# ---
#
# # 🖥️ PARTE 2: Demo do proxecto
#
# ### Instrucións
# 1. Copia aquí o **código principal** do teu proxecto (ou importa desde outro notebook)
# 2. Asegúrate de que **executa sen erros** de arriba abaixo
# 3. Prepara comentarios que expliquen o que fai cada parte
#
# > 💡 A demo debe durar **3–5 minutos**. Non hai que explicar todo o código, só o esencial.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 🔧 SETUP (librarías necesarias)
# ─────────────────────────────────────────────────────────────────────────────
# !pip -q install music21 librosa soundfile

# Importa aquí as túas librarías

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 🎵 CÓDIGO PRINCIPAL DO PROXECTO
# ─────────────────────────────────────────────────────────────────────────────

# Escribe aquí o código máis importante do teu proxecto
# Divide en seccións con comentarios claros

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 📊 RESULTADO / SAÍDA PRINCIPAL
# ─────────────────────────────────────────────────────────────────────────────

# Aquí debe aparecer o resultado máis importante:
# - Se é música simbólica: .show() ou exportar MIDI/XML
# - Se é audio: gráfica + reprodución
# - Se é análise: táboa ou visualización

# %% [markdown]
# ---
#
# # ✅ PARTE 3: Checklist de auto-avaliación
#
# Marca con **[x]** os elementos que cumpres. Sé honesto/a.
#
# ## Código e técnica
#
# - [ ] O código executa de arriba abaixo sen erros
# - [ ] O código está organizado en seccións con comentarios
# - [ ] Uso funcións para evitar repetición
# - [ ] Entendo o que fai cada liña do meu código
#
# ## Contido musical
#
# - [ ] O proxecto ten un obxectivo musical claro
# - [ ] Aplico conceptos vistos no curso (ritmo, melodía, harmonía, audio...)
# - [ ] O resultado soa/visualiza como esperaba
# - [ ] Podo explicar as decisións musicais que tomei
#
# ## Pensamento algorítmico musical
#
# - [ ] O código representa ideas musicais (non só cálculos)
# - [ ] Vexo conexións entre estruturas do código e estruturas musicais
# - [ ] Podo "ler" o código como unha partitura (secuencial, organizado)
#
# ## Proceso e reflexión
#
# - [ ] Probei varias ideas antes de chegar á versión final
# - [ ] Aprendín algo novo durante o proxecto
# - [ ] Sei explicar o que funcionou e o que non
# - [ ] Podo suxerir melloras futuras

# %% [markdown]
# ### 📊 Puntuación de auto-avaliación
#
# Conta os [x] marcados:
#
# | Elementos marcados | Nivel estimado |
# |-------------------|----------------|
# | 14–15 | Excelente |
# | 11–13 | Moi ben |
# | 8–10 | Adecuado |
# | 5–7 | Básico |
# | <5 | En progreso |
#
# **A miña puntuación:** ___/15

# %% [markdown]
# ---
#
# # 💭 PARTE 4: Reflexión final
#
# Responde con sinceridade (mínimo 8–10 liñas en total).
#
# ### 1) Que aprendín neste trimestre?
#
# *Escribe aquí...*
#
# ### 2) Que foi o máis difícil? Como o superaches?
#
# *Escribe aquí...*
#
# ### 3) Que faría diferente se empezase de novo?
#
# *Escribe aquí...*
#
# ### 4) Como me ven a min mesmo/a agora en relación á programación e a música?
#
# *Escribe aquí...*

# %% [markdown]
# ---
#
# # 🎤 PARTE 5: Presentación oral
#
# ## Guión suxerido (5 minutos máx.)
#
# 1. **Introdución** (30 seg.)
#    - Nome e título do proxecto
#    - Que quería conseguir
#
# 2. **Demo** (2–3 min.)
#    - Executar código e mostrar resultado
#    - Explicar os puntos clave
#
# 3. **Reflexión** (1 min.)
#    - Que aprendín
#    - Que melloraría
#
# 4. **Conclusión** (30 seg.)
#    - Mensaxe final
#
# > 📌 **Consello:** Non leas o código liña a liña. Explica **o que fai** e **por que**.

# %% [markdown]
# ---
#
# # 📝 PARTE 6: Feedback recibido
#
# Despois da presentación, anota aquí os comentarios do profesorado e compañeiros/as.
#
# ### Feedback do profesor/a:
#
# *...*
#
# ### Feedback dos compañeiros/as:
#
# *...*
#
# ### Ideas para mellorar (futuro):
#
# *...*

# %% [markdown]
# ---
#
# # 🏁 Entrega final
#
# ### Para entregar:
#
# 1. ✅ Este notebook completo (S12)
# 2. ✅ O notebook do proxecto (S10 + S11 ou versión consolidada)
# 3. ✅ Arquivos exportados (MIDI, MusicXML, WAV, PNG...)
#
# ### Formato de entrega:
#
# - Ligazón a Google Colab **ou**
# - Carpeta comprimida (.zip) subida á aula virtual
#
# ---
#
# ## 🎶 Parabéns por completar o curso!
#
# > *"Aprendemos a pensar música con código. Agora, o código é un instrumento máis."*
