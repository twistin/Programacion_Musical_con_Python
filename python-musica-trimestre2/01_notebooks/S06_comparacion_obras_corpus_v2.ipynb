# %% [markdown]
# # S06 v2 — Comparación computacional entre dúas obras (estilo, patróns, estatísticas)
# **Duración:** 1 sesión (≈ 1 hora)
# **Enfoque (Armonía):** usar datos para comparar repertorio
#
# ## 🎯 Obxectivos
# - Extraer métricas melódicas dunha voz (rango, intervalos, nota máis frecuente)
# - Extraer métricas harmónicas aproximadas (tipos de acordes / graos máis comúns)
# - Comparar dúas obras do corpus e interpretar diferenzas
#
# > Isto prepara directamente o salto a MIR/audio.

# %% [markdown]
# ## 0) Setup

# %%
# !pip -q install music21
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from music21 import corpus, note, interval, chord as m21chord
print("✅ listo")

# %% [markdown]
# ## 1) Cargar dúas obras

# %%
s1 = corpus.parse("bach/bwv66.6")
s2 = corpus.parse("bach/bwv269")  # outra coral
print("✅ cargadas")

# %% [markdown]
# ## 2) Métricas melódicas dunha voz (soprano por defecto)

# %%
def melodic_metrics(score, part_index=0):
    part = score.parts[part_index]
    ns = list(part.recurse().notes)
    midi = [n.pitch.midi for n in ns]
    names = [n.nameWithOctave for n in ns]
    # intervalos en semitonos
    semis = []
    for a,b in zip(ns, ns[1:]):
        semis.append(interval.Interval(a,b).semitones)
    semis_abs_mean = float(np.mean([abs(x) for x in semis])) if semis else 0.0
    return {
        "n_notas": len(ns),
        "rango_midi": int(max(midi)-min(midi)) if midi else 0,
        "intervalo_med_abs": semis_abs_mean,
        "nota_mais_frecuente": Counter(names).most_common(1)[0] if names else ("-",0)
    }

m1 = melodic_metrics(s1, 0)
m2 = melodic_metrics(s2, 0)
m1, m2

# %% [markdown]
# ## 3) Métricas harmónicas aproximadas (chordify)
# Contamos tipos de tríades/7ªs por nome común (aprox).

# %%
def harmonic_metrics(score, max_chords=80):
    ch = score.chordify()
    chords = list(ch.recurse().getElementsByClass(m21chord.Chord))[:max_chords]
    names = []
    for c in chords:
        try:
            names.append(c.commonName)
        except:
            names.append("Unknown")
    cnt = Counter(names)
    return {
        "n_chords": len(chords),
        "top_5_chord_types": cnt.most_common(5)
    }

h1 = harmonic_metrics(s1)
h2 = harmonic_metrics(s2)
h1, h2

# %% [markdown]
# ## 4) Comparación e visualización rápida

# %%
labels = ["rango_midi", "intervalo_med_abs"]
vals1 = [m1["rango_midi"], m1["intervalo_med_abs"]]
vals2 = [m2["rango_midi"], m2["intervalo_med_abs"]]

x = np.arange(len(labels))
w = 0.35
plt.figure()
plt.bar(x - w/2, vals1, width=w, label="Obra 1")
plt.bar(x + w/2, vals2, width=w, label="Obra 2")
plt.xticks(x, labels)
plt.title("Comparación melódica (voz 1)")
plt.legend()
plt.show()

# %% [markdown]
# ## 🧩 Tarefa (avaliable)
# 1) Cambia as obras (poden ser 2 corais de Bach ou 1 Bach vs outra obra).
# 2) Compara polo menos 3 métricas:
# - rango
# - intervalo medio
# - nota máis frecuente
# 3) Escribe unha interpretación (8–10 liñas):
# - que che din os datos do estilo?
# - coincide co que escoitarías/analizarías a man?
#
# > Nota: non buscamos “verdade absoluta”, buscamos **lectura crítica**.

# %%
# ✅ Espazo de traballo: cambia as obras aquí
# s1 = corpus.parse("bach/bwv153.1")
# s2 = corpus.parse("beethoven/opus18no1/movement1")  # pode tardar máis
